# %%
import pandas as pd
import numpy as np
base_loan = pd.read_csv(r'credit_train.csv')
base_loan
base_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100514 entries, 0 to 100513
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       100000 non-null  object
#  1   Customer ID                   100000 non-null  object
#  2   Loan Status                   100000 non-null  object
#  3   Current Loan Amount           100000 non-null  float64
#  4   Term                          100000 non-null  object
#  5   Credit Score                  80846 non-null   float64
#  6   Annual Income                 80846 non-null   float64
#  7   Years in current job          95778 non-null   object
#  8   Home Ownership                100000 non-null  object
#  9   Purpose                       100000 non-null  object
#  10  Monthly Debt                  100000 non-null  float64
#  11  Years of Credit History       100000 non-null  float64
# ...

# %%
base_loan
# Out:
#                                      Loan ID  \
# 0       14dd8831-6af5-400b-83ec-68e61888a048
# 1       4771cc26-131a-45db-b5aa-537ea4ba5342
# 2       4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3       77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 4       d4062e70-befa-4995-8643-a0de73938182
# ...                                      ...
# 100509                                   NaN
# 100510                                   NaN
# 100511                                   NaN
# 100512                                   NaN
# 100513                                   NaN
#
#                                  Customer ID Loan Status  Current Loan Amount  \
# 0       981165ec-3274-42f5-a3b4-d104041a9ca9  Fully Paid             445412.0
# 1       2de017a3-2e01-49cb-a581-08169e83be29  Fully Paid             262328.0
# 2       5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid           99999999.0
# 3       e777faab-98ae-45af-9a86-7ce5b33b1011  Fully Paid             347666.0
# ...

# %%
#Affichage des noms des variables de colonnes
for col in base_loan.select_dtypes(include='object').columns:
    print(col)
    print(base_loan[col].unique())
# Out:
# Loan ID
# ['14dd8831-6af5-400b-83ec-68e61888a048'
#  '4771cc26-131a-45db-b5aa-537ea4ba5342'
#  '4eed4e6a-aa2f-4c91-8651-ce984ee8fb26' ...
#  '81ab928b-d1a5-4523-9a3c-271ebb01b4fb'
#  'c63916c6-6d46-47a9-949a-51d09af4414f' nan]
# Customer ID
# ['981165ec-3274-42f5-a3b4-d104041a9ca9'
#  '2de017a3-2e01-49cb-a581-08169e83be29'
#  '5efb2b2b-bf11-4dfd-a572-3761a2694725' ...
#  '3e45ffda-99fd-4cfc-b8b8-446f4a505f36'
#  '1b3014be-5c07-4d41-abe7-44573c375886' nan]
# Loan Status
# ['Fully Paid' 'Charged Off' nan]
# Term
# ['Short Term' 'Long Term' nan]
# Years in current job
# ['8 years' '10+ years' '3 years' '5 years' '< 1 year' '2 years' '4 years'
#  '9 years' '7 years' '1 year' nan '6 years']
# Home Ownership
# ['Home Mortgage' 'Own Home' 'Rent' 'HaveMortgage' nan]
# Purpose
# ['Home Improvements' 'Debt Consolidation' 'Buy House' 'other'
#  'Business Loan' 'Buy a Car' 'major_purchase' 'Take a Trip' 'Other'
#  'small_business' 'Medical Bills' 'wedding' 'vacation'
# ...

# %%
#Matrice de correlation du tableau
base_loan.corr()
# Out:
#                               Current Loan Amount  Credit Score  \
# Current Loan Amount                      1.000000     -0.096652
# Credit Score                            -0.096652      1.000000
# Annual Income                            0.013112     -0.017078
# Monthly Debt                            -0.006643     -0.001674
# Years of Credit History                  0.019282     -0.009720
# Months since last delinquent             0.011248     -0.003739
# Number of Open Accounts                  0.001478      0.006435
# Number of Credit Problems               -0.002795     -0.003022
# Current Credit Balance                   0.003880     -0.000104
# Maximum Open Credit                     -0.001271     -0.002827
# Bankruptcies                            -0.000608     -0.006935
# Tax Liens                               -0.002048      0.005146
#
#                               Annual Income  Monthly Debt  \
# Current Loan Amount                0.013112     -0.006643
# ...

# %%
#remplacement de HaveMortgage par Home Mortgage
base_loanP= base_loan.replace(['HaveMortgage'],'Home Mortgage')

# %%
for col in base_loan.select_dtypes(include='object').columns:
    print(col)
    print(base_loan[col].unique())
# Out:
# Loan ID
# ['14dd8831-6af5-400b-83ec-68e61888a048'
#  '4771cc26-131a-45db-b5aa-537ea4ba5342'
#  '4eed4e6a-aa2f-4c91-8651-ce984ee8fb26' ...
#  '81ab928b-d1a5-4523-9a3c-271ebb01b4fb'
#  'c63916c6-6d46-47a9-949a-51d09af4414f' nan]
# Customer ID
# ['981165ec-3274-42f5-a3b4-d104041a9ca9'
#  '2de017a3-2e01-49cb-a581-08169e83be29'
#  '5efb2b2b-bf11-4dfd-a572-3761a2694725' ...
#  '3e45ffda-99fd-4cfc-b8b8-446f4a505f36'
#  '1b3014be-5c07-4d41-abe7-44573c375886' nan]
# Loan Status
# ['Fully Paid' 'Charged Off' nan]
# Term
# ['Short Term' 'Long Term' nan]
# Years in current job
# ['8 years' '10+ years' '3 years' '5 years' '< 1 year' '2 years' '4 years'
#  '9 years' '7 years' '1 year' nan '6 years']
# Home Ownership
# ['Home Mortgage' 'Own Home' 'Rent' nan]
# Purpose
# ['Home Improvements' 'Debt Consolidation' 'Buy House' 'other'
#  'Business Loan' 'Buy a Car' 'major_purchase' 'Take a Trip' 'Other'
#  'small_business' 'Medical Bills' 'wedding' 'vacation'
# ...

# %%
#Suppression des lignes lorsqu'une valeur de la ligne est nulle de la base base_loan2 (test)
base_loan2=base_loan2.dropna()

# %%
base_loan.shape
# Out:
# (100514, 19)

# %%
#Le tableau passe de 100 514 lignes à 36 423 lignes
base_loan2.shape
# Out:
# (36423, 19)

# %%
base_loan2.corr()
# Out:
#                               Current Loan Amount  Credit Score  \
# Current Loan Amount                      1.000000     -0.091345
# Credit Score                            -0.091345      1.000000
# Annual Income                            0.014758     -0.019661
# Monthly Debt                            -0.003642      0.008614
# Years of Credit History                  0.017056     -0.011369
# Months since last delinquent             0.012938     -0.003322
# Number of Open Accounts                  0.004405      0.013045
# Number of Credit Problems               -0.002140     -0.001187
# Current Credit Balance                   0.009030     -0.001974
# Maximum Open Credit                     -0.000508     -0.003887
# Bankruptcies                            -0.002362     -0.007259
# Tax Liens                               -0.003566      0.009064
#
#                               Annual Income  Monthly Debt  \
# Current Loan Amount                0.014758     -0.003642
# ...

# %%
base_loan2
# Out:
#                                     Loan ID  \
# 2      4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 6      273581de-85d8-4332-81a5-19b04ce68666
# 8      8af915d9-9e91-44a0-b5a2-564a45c12089
# 10     32c2e48f-1ba8-45e0-a530-9a6622c18d9c
# 12     403d7235-0284-4bb6-919a-09402fecbf7b
# ...                                     ...
# 99990  686017b3-dc24-4f8a-af92-0bd077452d3d
# 99993  79b81158-5d55-4766-8ad6-ebcd683f7d59
# 99994  8506a4e9-af7d-47d2-a1bf-7ea2c41858f0
# 99996  06eba04f-58fc-424a-b666-ed72aa008900
# 99997  e1cb4050-eff5-4bdb-a1b0-aabd3f7eaac7
#
#                                 Customer ID Loan Status  Current Loan Amount  \
# 2      5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid           99999999.0
# 6      90a75dde-34d5-419c-90dc-1e58b04b3e35  Fully Paid             217646.0
# 8      af534dea-d27e-4fd6-9de8-efaa52a78ec0  Fully Paid             548746.0
# 10     0de7bcdb-ebf4-4608-ba39-05f083f855b6  Fully Paid           99999999.0
# ...

# %%
#remplacer par 0 les NA dans la cooloone Months since last delinquent
base_loanP=base_loanP.dropna()
base_loanP["Months since last delinquent"].fillna(0, inplace = True)

# %%
base_loanP
# Out:
#                                      Loan ID  \
# 0       14dd8831-6af5-400b-83ec-68e61888a048
# 1       4771cc26-131a-45db-b5aa-537ea4ba5342
# 2       4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3       77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 4       d4062e70-befa-4995-8643-a0de73938182
# ...                                      ...
# 100509                                   NaN
# 100510                                   NaN
# 100511                                   NaN
# 100512                                   NaN
# 100513                                   NaN
#
#                                  Customer ID Loan Status  Current Loan Amount  \
# 0       981165ec-3274-42f5-a3b4-d104041a9ca9  Fully Paid             445412.0
# 1       2de017a3-2e01-49cb-a581-08169e83be29  Fully Paid             262328.0
# 2       5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid           99999999.0
# 3       e777faab-98ae-45af-9a86-7ce5b33b1011  Fully Paid             347666.0
# ...

# %%
#supprimer toutes les lignes vides de la base_loan
base_loan.dropna(axis=1,how='all')
base_loan
# Out:
#                                      Loan ID  \
# 0       14dd8831-6af5-400b-83ec-68e61888a048
# 1       4771cc26-131a-45db-b5aa-537ea4ba5342
# 2       4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3       77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 4       d4062e70-befa-4995-8643-a0de73938182
# ...                                      ...
# 100509                                   NaN
# 100510                                   NaN
# 100511                                   NaN
# 100512                                   NaN
# 100513                                   NaN
#
#                                  Customer ID Loan Status  Current Loan Amount  \
# 0       981165ec-3274-42f5-a3b4-d104041a9ca9  Fully Paid             445412.0
# 1       2de017a3-2e01-49cb-a581-08169e83be29  Fully Paid             262328.0
# 2       5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid           99999999.0
# 3       e777faab-98ae-45af-9a86-7ce5b33b1011  Fully Paid             347666.0
# ...

# %%
Remplacer les 99999999.0 par 0 dans la colonne 'Current Loan Amount'
base_loan3['Current Loan Amount']= base_loan['Current Loan Amount'].replace(99999999.0,0)

# %%
base_loan3
# Out:
#                                     Loan ID  \
# 2      4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 6      273581de-85d8-4332-81a5-19b04ce68666
# 8      8af915d9-9e91-44a0-b5a2-564a45c12089
# 10     32c2e48f-1ba8-45e0-a530-9a6622c18d9c
# 12     403d7235-0284-4bb6-919a-09402fecbf7b
# ...                                     ...
# 99990  686017b3-dc24-4f8a-af92-0bd077452d3d
# 99993  79b81158-5d55-4766-8ad6-ebcd683f7d59
# 99994  8506a4e9-af7d-47d2-a1bf-7ea2c41858f0
# 99996  06eba04f-58fc-424a-b666-ed72aa008900
# 99997  e1cb4050-eff5-4bdb-a1b0-aabd3f7eaac7
#
#                                 Customer ID Loan Status  Current Loan Amount  \
# 2      5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid                  0.0
# 6      90a75dde-34d5-419c-90dc-1e58b04b3e35  Fully Paid             217646.0
# 8      af534dea-d27e-4fd6-9de8-efaa52a78ec0  Fully Paid             548746.0
# 10     0de7bcdb-ebf4-4608-ba39-05f083f855b6  Fully Paid                  0.0
# ...

# %%
#Supprimer les lignes avec 99999999.0  dans la colonne 'Current Loan Amount'
#base_loanP['Current Loan Amount']= base_loanP['Current Loan Amount'].dropna(99999999.0)
